# %% [markdown]
#                                     ## WEB SCRAPING – ASSIGNMENT 4

# %% [markdown]
# #### v1. Scrape the details of most viewed videos on YouTube from Wikipedia. Url
# #### b= https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos You need to find following details: A)
# #### Rank
# #### ) Name
# #### C) Artist
# #### D) Upload date
# #### E) Views

# %%
import pandas as pd

# %%
import selenium

# %%
from  selenium import webdriver

# %%
from selenium.webdriver.common.by import By

# %%
import time

# %%
from  selenium.webdriver.common.keys import Keys

# %%
from selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException

# %%
from webdriver_manager.chrome import ChromeDriverManager

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos')

# %%
vid_rank=[]
nam=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[1]')
for i in nam:
    vid_rank.append(i.text)

# %%
vid_name=[]
name=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[2]')
for i in name:
    vid_name.append(i.text)

# %%
 vid_Artist=[]
art=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[3]')
for i in art:
     vid_Artist.append(i.text)

# %%
vid_Views=[]
Views=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[4]')
for i in Views:
    vid_Views.append(i.text)

# %%
Upload_date=[]
data=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[5]')
for i in data:
    Upload_date.append(i.text)

# %%
len(Upload_date),len(vid_Views),len(vid_Artist),len(vid_name),len(vid_rank)
# Out:
# (30, 30, 30, 30, 30)

# %%
import pandas as pd

# %%
most_views_video=pd.DataFrame({'vid_rank':vid_rank,'vid_name':vid_name,'vid_Artist':vid_Artist,'vid_Views':vid_Views,'Upload_date':Upload_date})

# %%
most_views_video
# Out:
#    vid_rank                                         vid_name  \
# 0        1.                            "Baby Shark Dance"[6]
# 1        2.                                   "Despacito"[9]
# 2        3.                       "Johny Johny Yes Papa"[17]
# 3        4.                                  "Bath Song"[18]
# 4        5.                               "Shape of You"[19]
# 5        6.                              "See You Again"[22]
# 6        7.                          "Wheels on the Bus"[27]
# 7        8.                "Phonics Song with Two Words"[28]
# 8        9.                                "Uptown Funk"[29]
# 9       10.  "Learning Colors – Colorful Eggs on a Farm"[30]
# 10      11.                              "Gangnam Style"[31]
# 11      12.   "Masha and the Bear – Recipe for Disaster"[36]
# 12      13.                             "Dame Tu Cosita"[37]
# 13      14.                                     "Axel F"[38]
# ...

# %%
driver.close()

# %% [markdown]
# #### 2. Scrape the details team India’s international fixtures from bcci.tv.
# #### Url = https://www.bcci.tv/.
# #### You need to find following details:
# #### A) Series
# #### B) Place
# #### C) Date
# #### D) Time
# #### Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.bcci.tv/')

# %%
fixcher=driver.find_element(By.XPATH,'/html/body/header/div[3]/div[1]/ul/div[1]/a[2]')
fixcher.click()

# %%
series=[]
ser=driver.find_elements(By.XPATH,'//h5[@class="match-tournament-name ng-binding"]')
for i in ser:
    try:
        ser
        series.append(i.text)
    except NoSuchElementExceptions:
            series.append('____')

# %%
place=[]
plac=driver.find_elements(By.XPATH,'//div[@class="match-place ng-scope"]/span[1]')
for i in plac:
    place.append(i.text)

# %%
match_date=[]
dte=driver.find_elements(By.XPATH,'//div[@class="match-dates ng-binding"]')
for i in dte:
    match_date.append(i.text)

# %%
match_time=[]
time=driver.find_elements(By.XPATH,'//div[@class="match-time no-margin ng-binding"]')
for i in time:
    match_time.append(i.text)

# %%
len(match_time),len(match_date),len(place),len(series)
# Out:
# (211, 211, 211, 211)

# %%
 India_international_fixtures=pd.DataFrame({'series':series,'place':place,'match_date':match_date,'match_time':match_time})

# %%
India_international_fixtures
# Out:
#                           series  \
# 0        ICC MENS WORLD CUP 2023
# 1        ICC MENS WORLD CUP 2023
# 2        ICC MENS WORLD CUP 2023
# 3        ICC MENS WORLD CUP 2023
# 4        ICC MENS WORLD CUP 2023
# ..                           ...
# 206                ASIA CUP 2022
# 207                ASIA CUP 2022
# 208  NEW ZEALAND A TOUR OF INDIA
# 209                ASIA CUP 2022
# 210                ASIA CUP 2022
#
#                                                  place         match_date  \
# 0             Maharashtra Cricket Association Stadium,   19 OCTOBER, 2023
# 1        Himachal Pradesh Cricket Association Stadium,   22 OCTOBER, 2023
# 2    Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...   29 OCTOBER, 2023
# 3                                    Wankhede Stadium,   2 NOVEMBER, 2023
# 4                                        Eden Gardens,   5 NOVEMBER, 2023
# ..                                                 ...                ...
# ...

# %%
driver.close()

# %% [markdown]
# #### 3. Scrape the details of State-wise GDP of India from statisticstime.com.
# #### Url = http://statisticstimes.com/
# #### You have to find following details: A) Rank
# #### B) State
# #### C) GSDP(18-19)- at current prices
# #### D) GSDP(19-20)- at current prices
# #### E) Share(18-19)
# #### F) GDP($ billion)
# #### Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://statisticstimes.com/index.php')

# %%
driver.find_element(By.XPATH,"//div[@class='navbar']/div[2]/button").click()

driver.find_element(By.XPATH,"//div[@class='dropdown-content']/a[3]").click()
time.sleep(3)

# %%
GDPI = driver.find_element(By.XPATH,"/html/body/div[2]/div[2]/div[2]/ul/li[1]/a")
GDPI.click()
time.sleep(3)

# %%
Rank = []
State = []
GSDP18 = []
GSDP19 = []
Share = []
GDP_billion = []

# %%
r= driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[1]")

# %%
try:
    for i in r:
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append('___')

# %%
stat=driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[2]")
try:
    for i in stat:
        State.append(i.text)
except NoSuchElementException:
        State.append('__')

# %%
gdp1=driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[3]")
try:
    for i in gdp1:
        GSDP18.append(i.text)
except NoSuchElementException:
    GSDP18.append(i.text)

# %%
gdp2=driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[4]")
try:
    for i in gdp2:
        GSDP19.append(i.text)
except NoSuchElementException:
    GSDP19.append('__')

# %%
part=driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[5]")
try:
    for i in part:
        Share.append(i.text)
except NoSuchElementException:
    Share.append('__')

# %%
GDPB=driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[6]")
try:
    for i in GDPB:
        GDP_billion.append(i.text)
except NoSuchElementException:
    GDP_billion.append('__')

# %%
len(GDP_billion),len(Share),len(GSDP19),len(GSDP18),len(State),len(Rank)
# Out:
# (66, 66, 66, 66, 66, 66)

# %%
GDP_of_INDIA=pd.DataFrame({'Rank':Rank,'State':State,'GSDP18':GSDP18,'GSDP19':GSDP19,'Share':Share,'GDP_billion':GDP_billion})

# %%
GDP_of_INDIA
# Out:
#    Rank                      State     GSDP18     GSDP19   Share GDP_billion
# 0     1                Maharashtra          -  2,632,792  13.94%     399.921
# 1     2                 Tamil Nadu  1,845,853  1,630,208   8.63%     247.629
# 2     3              Uttar Pradesh  1,687,818  1,584,764   8.39%     240.726
# 3     4                    Gujarat          -  1,502,899   7.96%     228.290
# 4     5                  Karnataka  1,631,977  1,493,127   7.91%     226.806
# ..  ...                        ...        ...        ...     ...         ...
# 61   29                     Sikkim     28,391     25,141   0.15%      17,060
# 62   30                   Nagaland          -     24,534   0.15%           -
# 63   31          Arunachal Pradesh          -     22,488   0.13%           -
# 64   32                    Mizoram     24,424     20,947   0.13%      17,797
# 65   33  Andaman & Nicobar Islands          -          -       -           -
#
# [66 rows x 6 columns]

# %%
driver.close()

# %% [markdown]
# #### 4. Scrape the details of trending repositories on Github.com.
# #### Url = https://github.com/
# #### You have to find the following details:
# #### A) Repository title
# #### B) Repository description
# #### C) Contributors count
# #### D) Language used

# %%
driver=webdriver.Chrome()

# %%
driver.get(' https://github.com/')

# %%
open_sourse=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/button')
open_sourse.click()
time.sleep(3)

trending=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/div[3]/ul/li[2]/a')
trending.click()
time.sleep(3)

# %%
Repository_url=[]
title=driver.find_elements(By.XPATH,'//a[@class="Link"]')
try:
    for i in title:
        Repository_url.append(i.get_attribute('href'))
except NoSuchElementException:
    Repository_url.append('___')

# %%
Repository_title=[]
for i in Repository_url:
    driver.get(i)
    time.sleep(4)
    try:
        titl=driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/main/div/div[1]/div[1]/div/strong/a')
        Repository_title.append(titl.text)
    except NoSuchElementException:
        Repository_title.append('__')

# %%
Repository_description=[]
Contributors_count=[]
Language_used=[]    
for i in Repository_url:
    driver.get(i)
    time.sleep(5)
    try:
        desc=driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/main/turbo-frame/div/div/div/div[2]/div[2]/div/div[1]/div/p')
        Repository_description.append(desc.text)
    except NoSuchElementException:
        Repository_description.append('__')
    try:
        count=driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/main/turbo-frame/div/div/div/div[2]/div[2]/div/div[3]/div/h2/a/span')
        Contributors_count.append(count.text)
    except NoSuchElementException:
        Contributors_count.append('__')
    try:
        lng=driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/main/turbo-frame/div/div/div/div[2]/div[2]/div/div[5]/div/ul/li[1]/a/span[1]')
        Language_used.append(lng.text)
    except NoSuchElementException:
        Language_used.append('__')

# %%
len(Repository_description),len(Contributors_count),len(Language_used),len(Repository_title)
# Out:
# (25, 25, 25, 25)

# %%
gitHuB_trendin=pd.DataFrame({'Repository_title':Repository_title,'Repository_description':Repository_description,'Contributors_count':Contributors_count,'Language_used':Language_used})

# %%
gitHuB_trendin
# Out:
#              Repository_title  \
# 0          ChatGPT-AutoExpert
# 1       PokemonRedExperiments
# 2                     LazyVim
# 3              tact-challenge
# 4                     pi-hole
# 5                      Python
# 6   text-embeddings-inference
# 7          awesome-selfhosted
# 8                      uBlock
# 9      project-based-learning
# 10               travel_ui_ux
# 11                    cal.com
# 12             kickstart.nvim
# 13                   Hyprland
# 14                 formbricks
# 15            snowden-archive
# 16                   Sunshine
# 17             docker-roadmap
# 18                   leetcode
# 19                4DGaussians
# 20                     Magisk
# 21                    czkawka
# 22                 nodejs.org
# 23                    MetaGPT
# 24              Cataclysm-DDA
#
#                                Repository_description Contributors_count  \
# 0   🚀🧠💬 Supercharged Custom Instructions for ChatG...                 __
# ...

# %%
driver.close()

# %% [markdown]
# #### 5. Scrape the details of top 100 songs on billiboard.com. Url = https:/www.billboard.com/ You have to find the
# #### following details:
# #### A) Song name
# #### B) Artist name
# #### C) Last week rank
# #### D) Peak rank
# #### E) Weeks on board
# #### Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.billboard.com/')

# %%
top=driver.find_element(By.XPATH,'/html/body/div[3]/header/div/div[3]/div/nav/ul/li[4]/a')
top.click()

# %%
current_rank=[]
no=driver.find_elements(By.XPATH,'//span[@class="c-label  a-font-primary-bold-l u-font-size-32@tablet u-letter-spacing-0080@tablet"]')
try:
    for i in no:
        current_rank.append(i.text)
except NoSuchElementException:
    current_rank.append('__')

# %%
Artist_name=[]
art=driver.find_elements(By.XPATH,'//ul[@class="lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max"]/li[1]/span')
try:
    for i in art:
        Artist_name.append(i.text)
except NoSuchElementException:
    Artist_name.append('____')

# %%
Last_week_rank=[]
lwr=driver.find_elements(By.XPATH,'//ul[@class="lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max"]/li[4]')    
try:
    for i in lwr:
        Last_week_rank.append(i.text)
except NoSuchElementException:
    Last_week_rank.append('____')

# %%
Peak_rank=[]
pr=driver.find_elements(By.XPATH,'//ul[@class="lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max"]/li[5]')
try:
    for i in pr:
        Peak_rank.append(i.text)
except NoSuchElementException:
    Peak_rank.append('__')

# %%
Weeks_on_board=[]
wob=driver.find_elements(By.XPATH,'//ul[@class="lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max"]/li[6]')
try:
    for i in wob:
        Weeks_on_board.append(i.text)
except NoSuchElementException:
    Weeks_on_board.append('___')

# %%
len(Weeks_on_board),len(Peak_rank),len(Last_week_rank),len(Artist_name),len(song_name),
# Out:
# (100, 100, 100, 100, 100)

# %%
top_100_song=pd.DataFrame({'song_name':song_name,'Artist_name':Artist_name,'Last_week_rank':Last_week_rank,'Peak_rank':Peak_rank
                          ,'Weeks_on_board':Weeks_on_board})

# %%
top_100_song
# Out:
#                song_name                          Artist_name Last_week_rank  \
# 0   First Person Shooter              Drake Featuring J. Cole              -
# 1                  IDGAF                 Drake Featuring Yeat              -
# 2         Virginia Beach                                Drake              -
# 3     Paint The Town Red                             Doja Cat              1
# 4        Calling For You            Drake Featuring 21 Savage              -
# ..                   ...                                  ...            ...
# 95    God Gave Me A Girl                    Russell Dickerson             90
# 96               Y Lloro                             Junior H              -
# 97           Telekinesis  Travis Scott Featuring SZA & Future             72
# 98                 Seven            Jung Kook Featuring Latto             57
# 99   Stars Like Confetti                         Dustin Lynch             89
#
#    Peak_rank Weeks_on_board
# ...

# %%
driver.close()

# %% [markdown]
# #### 6. Scrape the details of Highest selling novels.
# #### A) Book name
# #### B) Author name
# #### C) Volumes sold
# #### D) Publisher
# #### E) Genre
# #### Url - https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare

# %%
driver=webdriver.Chrome()

# %%
driver.get(' https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare')

# %%
Book_name=[]
book_n=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[2]')
try:
    for i in book_n:
        Book_name.append(i.text)
except NoSuchElementException:
    Book_name.append('__')

# %%
Author_name=[]
author_n=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[3]')  
try:
    for i in author_n:
        Author_name.append(i.text)
except NoSuchElementException:
    Author_name.append('___')

# %%
Volumes_sold=[]
volume=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[4]')
try:
    for i in volume:
        Volumes_sold.append(i.text)
except NoSuchElementException:
    Volumes_sold.append('___')

# %%
Publisher=[]
public=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[5]') 
try:
    for i in public:
        Publisher.append(i.text)
except NoSuchElementException:
    Publisher.append('____')

# %%
Genre=[]
type_=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[6]')
try:
    for i in type_:
        Genre.append(i.text)
except NoSuchElementException:
    Genre.append('____')

# %%
len(Genre),len(Book_name),len(Author_name),len(Volumes_sold),len(Publisher)
# Out:
# (100, 100, 100, 100, 100)

# %%
highest_selling_novels=pd.DataFrame({'Book_name':Book_name,'Author_name':Author_name,'Volumes_sold':Volumes_sold
                                     ,'Publisher':Publisher,'Genre':Genre})

# %%
highest_selling_novels
# Out:
#                                             Book_name       Author_name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes_sold        Publisher                        Genre
# ...

# %%
driver.close()

# %% [markdown]
# #### 7. Scrape the details most watched tv series of all time from imdb.com.
# #### Url = https://www.imdb.com/list/ls095964455/ You have
# #### to find the following details:
# #### A) Name
# #### B) Year span
# #### C) Genre
# #### D) Run time
# #### E) Ratings
# #### F) Votes

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.imdb.com/list/ls095964455/')

# %%
series_name=[]
se_name=driver.find_elements(By.XPATH,'//h3[@class="lister-item-header"]/a')
try:
    for i in se_name:
        series_name.append(i.text)
except NoSuchElementException:
    series_name.append('____')

# %%
Year_span=[]
span=driver.find_elements(By.XPATH,'//h3[@class="lister-item-header"]/span[2]')
try:
    for i in span:
        Year_span.append(i.text)
except NoSuchElementException:
    Year_span.append('____')

# %%
Genre_of_series=[]
gos=driver.find_elements(By.XPATH,'//h3[@class="lister-item-header"]/span[2]')
try:
    for i in gos:
        Genre_of_series.append(i.text)
except NoSuchElementException:
    Genre_of_series.append('____')

# %%
Run_time=[]
run=driver.find_elements(By.XPATH,'//div[@class="lister-item-content"]/p/span[3]')
try:
    for i in run:
        Run_time.append(i.text)
except NoSuchElementException:
    Run_time.append('____')

# %%
series_Ratings=[]
ser=driver.find_elements(By.XPATH,'//div[@class="ipl-rating-widget"]/div/span[2]')
try:
    for i in ser:
        series_Ratings.append(i.text)
except NoSuchElementException:
    series_Ratings.append('____')

# %%
Votes=[]
vot=driver.find_elements(By.XPATH,'//span[@name="nv"]')
try:
    for i in vot:
        Votes.append(i.text)
except NoSuchElementException:
    Votes.append('____')

# %%
len(series_name),len(Year_span),len(Genre_of_series),len(Run_time),len(series_Ratings),len(Votes)
# Out:
# (100, 100, 100, 100, 100, 100)

# %%
most_watched_tv_series=pd.DataFrame({'series_name':series_name,'Year_span':Year_span,'Genre_of_series':Genre_of_series,'Run_time':Run_time,'series_Ratings':series_Ratings,'Votes':Votes})

# %%
most_watched_tv_series
# Out:
#                        series_name    Year_span Genre_of_series Run_time  \
# 0                  Game of Thrones  (2011–2019)     (2011–2019)   57 min
# 1                  Stranger Things  (2016–2025)     (2016–2025)   51 min
# 2                 The Walking Dead  (2010–2022)     (2010–2022)   44 min
# 3                   13 Reasons Why  (2017–2020)     (2017–2020)   60 min
# 4                          The 100  (2014–2020)     (2014–2020)   43 min
# ..                             ...          ...             ...      ...
# 95                           Reign  (2013–2017)     (2013–2017)   42 min
# 96  A Series of Unfortunate Events  (2017–2019)     (2017–2019)   50 min
# 97                  Criminal Minds     (2005– )        (2005– )   42 min
# 98           Scream: The TV Series  (2015–2019)     (2015–2019)   45 min
# 99      The Haunting of Hill House       (2018)          (2018)  572 min
#
#    series_Ratings      Votes
# 0             9.2  2,213,469
# 1             8.7  1,283,253
# ...

# %%
driver.close()

# %% [markdown]
# #### 8. Details of Datasets from UCI machine learning repositories.
# #### Url = https://archive.ics.uci.edu/ You
# #### have to find the following details:
# #### A) Dataset name
# #### B) Data type
# #### C) Task
# #### D) Attribute type
# #### E) No of instances
# #### F) No of attribute G) Year
# #### Note: - from the home page you have to go to the Show All Dataset page through code.

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://archive.ics.uci.edu/ You¶')

# %%
datasets=driver.find_element(By.XPATH,'/html/body/div/div[1]/div[1]/header/nav/ul/li[1]/a')
datasets.click()

# %%
rowspp=driver.find_element(By.XPATH,'/html/body/div/div[1]/div[1]/main/div/div[2]/div[3]/label/select')
rowspp.click()
time.sleep(3)
option25=driver.find_element(By.XPATH,'/html/body/div/div[1]/div[1]/main/div/div[2]/div[3]/label/select/option[5]')
option25.click()
time.sleep(2)

# %%
exp_all=driver.find_element(By.XPATH,'/html/body/div/div[1]/div[1]/main/div/div[2]/div[1]/div/label[2]')
exp_all.click()

# %%
Dataset_name=[]
Data_type=[]
Task=[]
Attribute_type=[]
No_of_instances=[]
No_of_attribute=[]
Year=[]

# %%
dataset_n=driver.find_elements(By.XPATH,'//div[@class="relative col-span-8 sm:col-span-7"]/h2/a')
start=0
end=26
try:
    for page in range(start,end):
        for i in dataset_n:
            Dataset_name.append(i.text)
except NoSuchElementException:
    Dataset_name.append('____')
    next_=driver.find_element(By.XPATH,'/html/body/div/div[1]/div[1]/main/div/div[2]/div[3]/div/button[2]')
    next_.click()
    time.sleep(5)

# %%
dataset_t=driver.find_elements(By.XPATH,'//div[@class="my-2 hidden gap-4 md:grid grid-cols-12"]/div[2]/span')
start=0
end=26
try:
    for page in range(start,end):
        for i in dataset_t:
            Data_type.append(i.text)
except NoSuchElementException:
    Data_type.append('___')
    next_=driver.find_element(By.XPATH,'/html/body/div/div[1]/div[1]/main/div/div[2]/div[3]/div/button[2]')
    next_.click()
    time.sleep(5)

# %%
dataset_ta=driver.find_elements(By.XPATH,'//div[@class="my-2 hidden gap-4 md:grid grid-cols-12"]/div[1]/span')
start=0
end=26
try:
    for page in range(start,end):
        for i in dataset_ta:
            Task.append(i.text)
except NoSuchElementException:
    Task.append('___')
    next_=driver.find_element(By.XPATH,'/html/body/div/div[1]/div[1]/main/div/div[2]/div[3]/div/button[2]')
    next_.click()
    time.sleep(5)

# %%
dataset_at=driver.find_elements(By.XPATH,'//tbody[@class="border"]/tr/td[2]')
start=0
end=26
try:
    for page in range(start,end):
        for i in dataset_at:
            Attribute_type.append(i.text)
except NoSuchElementException:
    Attribute_type.append('___')
    next_=driver.find_element(By.XPATH,'/html/body/div/div[1]/div[1]/main/div/div[2]/div[3]/div/button[2]')
    next_.click()
    time.sleep(5)

# %%
dataset_noi=driver.find_elements(By.XPATH,'//div[@class="my-2 hidden gap-4 md:grid grid-cols-12"]/div[3]/span')
start=0
end=26
try:
    for page in range(start,end):
        for i in dataset_noi:
            No_of_instances.append(i.text)
except NoSuchElementException:
    No_of_instances.append('___')
    next_=driver.find_element(By.XPATH,'/html/body/div/div[1]/div[1]/main/div/div[2]/div[3]/div/button[2]')
    next_.click()
    time.sleep(5)

# %%
dataset_noa=driver.find_elements(By.XPATH,'//div[@class="my-2 hidden gap-4 md:grid grid-cols-12"]/div[4]/span')
start=0
end=26
try:
    for page in range(start,end):
        for i in dataset_noa:
            No_of_attribute.append(i.text)
except NoSuchElementException:
    No_of_attribute.append('___')
    next_=driver.find_element(By.XPATH,'/html/body/div/div[1]/div[1]/main/div/div[2]/div[3]/div/button[2]')
    next_.click()
    time.sleep(5)

# %%
dataset_Y=driver.find_elements(By.XPATH,'//tbody[@class="border"]/tr/td[3]')
start=0
end=26
try:
    for page in range(start,end):
        for i in dataset_Y:
            Year.append(i.text)
except NoSuchElementException:
    Year.append('___')
    next_=driver.find_element(By.XPATH,'/html/body/div/div[1]/div[1]/main/div/div[2]/div[3]/div/button[2]')
    next_.click()
    time.sleep(5)

# %%
len(Year),len(Data_type),len(Dataset_name),len(Task),len(Attribute_type),len(No_of_instances),len(No_of_attribute)
# Out:
# (650, 650, 650, 650, 650, 650, 650)

# %%
Uci_ML_repastory=pd.DataFrame({'Dataset_name':Dataset_name,'Data_type':Data_type,'Task':Task,'Attribute_type':Attribute_type,'No_of_instances':No_of_instances,'No_of_attribute':No_of_attribute,'Year':Year})

# %%
Uci_ML_repastory
# Out:
#                                        Dataset_name  \
# 0                                              Iris
# 1                                     Heart Disease
# 2                                             Adult
# 3                                              Wine
# 4              Breast Cancer Wisconsin (Diagnostic)
# ..                                              ...
# 645                             Student Performance
# 646                                 Thyroid Disease
# 647                                        Spambase
# 648  Predict students' dropout and academic success
# 649                                   Online Retail
#
#                                  Data_type                        Task  \
# 0                                  Tabular              Classification
# 1                             Multivariate              Classification
# 2                             Multivariate              Classification
# ...
